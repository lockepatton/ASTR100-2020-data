# %%
from astropy.table import QTable
import numpy as np
import matplotlib as plt

import glob
import pandas as pd

import itertools

# %%
# with open('2016071810EB1_001.fits.als.1') as f_in:
#         x = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
        
# with open('2016071810EB1_002.fits.als.1') as f_in:
#         y = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])

# z = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])

# print x
# print y

# %%
# T = QTable.read('2016071810EB1_001.fits.als.1',format='ascii', delimiter='\t', header_start=0)
# , names='[N,ID,XCENTER,YCENTER,MAG,MERR,MSKY,NITER,SHARPNESS,CHI,PIER,PERROR]'
# T = np.genfromtxt('2016071810EB1_001.fits.als.1',usecols=(0,1,2,3))
# T1=T[0::2]
# T2=T[1::2]
# k = np.array(T1, dtype={'names':['N','ID','XCENTER','YCENTER'], 'formats':['f4','f4','f4','f4']})
# k = np.zeros(3, dtype={'names':['col1', 'col2'], 'formats':['i4','f4']})
# print k[1]

# %%
# path =r'/Users/amielpatton-hall/Desktop/ASTR481/data/Observingtrip3/20160718/allstar' # use your path
# allFiles = glob.glob(path + "/*")

# list_ = []
# frame = pd.DataFrame()
# for file_ in allFiles:
# #     df = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
# #     df = QTable.read(file_,format='ascii', delimiter=' ', header_start=42)
#     list_.append(df)
# frame = pd.concat(list_)

# %%
path =r'/Users/amielpatton-hall/Desktop/ASTR481/data/Observingtrip3/20160718/allstar'
allFiles = glob.glob(path + "/*1")
# allFiles = glob.glob("*1")

for i in xrange(len(allFiles)):
    file_ = allFiles[i]
#     print file_
    table_name = 'Table' + str(i)
#     print table_name
    with open(file_) as f_in:
        table = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
#         print table
        np.savetxt(table_name, table, delimiter=',', fmt='%.5f')

#         with open(file_) as f_in:
# #         count_list = [i+1 for i in xrange(len(allFiles))]
#             print np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
        
# for file_ in allFiles:
#         print file_
#         with open(file_) as f_in:
#             print np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
        

        
# for file_ in allFiles:
#     with open(file_) as f_in:
#         y = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])

#     T['file_'] =  np.genfromtxt(itertools.islice(file_, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
#     file_ = np.genfromtxt(itertools.islice(file_, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
#     print T['file_']
# Out:
# /Users/amielpatton-hall/Desktop/ASTR481/data/Observingtrip3/20160718/allstar/2016071810EB1_001.fits.als.1
# Table0
# [(36.0, 12.719, 152.453, 14.938, 0.11, 233.2297, 4.0)
#  (119.0, 155.708, 388.623, 16.671, 0.075, 232.9396, 4.0)
#  (1.0, 72.926, 3.555, 14.78, 0.13, 233.6186, 5.0)
#  (14.0, 501.015, 48.627, 13.756, 0.099, 233.5908, 5.0)
#  (23.0, 86.865, 104.344, 16.842, 0.118, 231.6176, 5.0)
#  (30.0, 289.83, 126.942, 16.506, 0.091, 233.9215, 5.0)
#  (32.0, 329.969, 138.393, 17.232, 0.106, 236.6783, 5.0)
#  (39.0, 433.467, 161.348, 18.291, 0.213, 229.6424, 5.0)
#  (43.0, 239.582, 165.889, 17.227, 0.105, 238.0681, 5.0)
#  (60.0, 33.931, 204.049, 13.813, 0.097, 234.9565, 5.0)
#  (61.0, 62.906, 212.868, 17.149, 0.098, 234.0462, 5.0)
#  (67.0, 149.484, 233.58, 17.698, 0.116, 232.5948, 5.0)
#  (90.0, 182.557, 281.164, 17.139, 0.085, 231.3059, 5.0)
#  (113.0, 201.27, 363.204, 15.071, 0.088, 233.5935, 5.0)
#  (4.0, 226.683, 11.753, 17.243, 0.158, 231.4726, 6.0)
# ...

# %%
# path =r'/Users/amielpatton-hall/Desktop/ASTR481/data/Observingtrip3/20160718/allstar'
# allFiles = glob.glob(path + "/*1")
# # allFiles = glob.glob("*1")

# for i in xrange(len(allFiles)):
#     file_ = allFiles[i]
#     print file_
#     table_name = 'Table' + str(i)
#     print table_name
#     with open(file_) as f_in:
#         table = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
# #         print table
# #         np.savetxt(table_name, table, delimiter=',', fmt='%.5f') #, header = ["N","ID","XCENTER","YCENTER","MAG","MERR","MSKY","NITER","SHARPNESS","CHI","PIER","PERROR"])



# #         with open(file_) as f_in:
# # #         count_list = [i+1 for i in xrange(len(allFiles))]
# #             print np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
        
# # for file_ in allFiles:
# #         print file_
# #         with open(file_) as f_in:
# #             print np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
        

        
# # for file_ in allFiles:
# #     with open(file_) as f_in:
# #         y = np.genfromtxt(itertools.islice(f_in, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])

# #     T['file_'] =  np.genfromtxt(itertools.islice(file_, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
# #     file_ = np.genfromtxt(itertools.islice(file_, 0, None, 2), dtype=[('ID', '<f8'), ('XCENTER', '<f8'),('YCENTER', '<f8'),('MAG', '<f8'),('MERR', '<f8'), ('MSKY', '<f8'),('NITER', '<f8')])
# #     print T['file_']
